# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('IMDB.csv.xls')

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# ...

# %%
len(data)
# Out:
# 1000

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.isnull().sum(axis=0)
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    0
# 997    0
# 998    1
# 999    0
# Length: 1000, dtype: int64

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
# to check  missing value
data.isnull().values.any()
# Out:
# True

# %%
# showing null values as percentage
data1=data.isnull().sum(axis=0)

# %%
data2=data1/len(data)*100

# %%
data2
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
len(data)
# Out:
# 1000

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # drop all the missing values
# data.dropna(axis=0)

# %%
data.dropna(axis=0)
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 7. Check For Duplicate Data.

# %%
data.duplicated().any()
# Out:
# False

# %%
data.drop_duplicates().any()
# Out:
# Rank                  True
# Title                 True
# Genre                 True
# Description           True
# Director              True
# Actors                True
# Year                  True
# Runtime (Minutes)     True
# Rating                True
# Votes                 True
# Revenue (Millions)    True
# Metascore             True
# dtype: bool

# %%
# display title of the movie having runtime greater than or equal to 180 minutes

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Runtime (Minutes)']>=180][['Title','Runtime (Minutes)']]
# Out:
#                        Title  Runtime (Minutes)
# 82   The Wolf of Wall Street                180
# 88         The Hateful Eight                187
# 311           La vie d'Adèle                180
# 828               Grindhouse                191
# 965            Inland Empire                180

# %%
# showing null values as percentage
data.isnull().sum(axis=0)/len(data)*100
# Out:
# Rank                   0.0
# Title                  0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %%
# in which  year there was the highest  average voting?
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False).head(1)
# Out:
# Year
# 2012    285226.09375
# Name: Votes, dtype: float64

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title('Votes by Year')
plt.show()

# %% [markdown]
# # 11. in which year there was the highest average average reveneue

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data1=data.groupby('Year')['Revenue (Millions)'].mean()

# %%
data1[data1.max()==data1]
# Out:
# Year
# 2009    112.601277
# Name: Revenue (Millions), dtype: float64

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title('Revenue by Year')
plt.show()

# %% [markdown]
# # Find the Average Rating for each Director
# data.columns

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %%
sns.barplot(x='Director',y='Rating',data=data)
plt.title('Director by Rating')
plt.show()

# %% [markdown]
# # display Top 10 lengthy movie's Title and Runtime

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.groupby('Title')['Runtime (Minutes)'].max().sort_values(ascending=False).head(10)
# Out:
# Title
# Grindhouse                                  191
# The Hateful Eight                           187
# Inland Empire                               180
# The Wolf of Wall Street                     180
# La vie d'Adèle                              180
# Cloud Atlas                                 172
# 3 Idiots                                    170
# Interstellar                                169
# Pirates of the Caribbean: At World's End    169
# The Hobbit: An Unexpected Journey           169
# Name: Runtime (Minutes), dtype: int64

# %%
top_10=data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')
top_10
# Out:
#                                           Runtime (Minutes)
# Title
# Grindhouse                                              191
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Inland Empire                                           180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169

# %%
sns.barplot(data=top_10,x='Runtime (Minutes)', y=top_10.index)
plt.title("Top 10 Lengthy Movie's Title and Runtime")
plt.show()

# %% [markdown]
# # Display Number of movies per year
# # count plot

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data2=data.groupby('Year')['Title'].count()

# %%
data2
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Title, dtype: int64

# %%
data['Year'].value_counts()
# Out:
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: Year, dtype: int64

# %%
sns.countplot( data=data,x='Year')
plt.title("Number of Movies per year")
plt.show()

# %%
# find most popular movie Title (highest Revenue)
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Revenue (Millions)'].max()==data['Revenue (Millions)']][['Title','Revenue (Millions)']]
# Out:
#                                          Title  Revenue (Millions)
# 50  Star Wars: Episode VII - The Force Awakens              936.63

# %% [markdown]
# # 16. Display Top Highest Rated movie titles and its directors

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
index=data['Rating'].sort_values(ascending=False).head(10).index
index
# Out:
# Int64Index([54, 80, 117, 36, 96, 249, 133, 64, 99, 991], dtype='int64')

# %%
data.iloc[index][['Title','Director','Rating']]
# Out:
#                 Title           Director  Rating
# 54    The Dark Knight  Christopher Nolan     9.0
# 80          Inception  Christopher Nolan     8.8
# 117            Dangal      Nitesh Tiwari     8.8
# 36       Interstellar  Christopher Nolan     8.6
# 96      Kimi no na wa     Makoto Shinkai     8.6
# 249  The Intouchables    Olivier Nakache     8.6
# 133          Whiplash    Damien Chazelle     8.5
# 64       The Prestige  Christopher Nolan     8.5
# 99       The Departed    Martin Scorsese     8.5
# 991  Taare Zameen Par         Aamir Khan     8.5

# %%
top_10data=data.nlargest(10,'Rating')[['Title','Rating', 'Director']].set_index('Title')

# %%
sns.barplot(y=top_10data.index,x='Rating', data=top_10data, hue='Director',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)
plt.show()

# %%
# 17. Display Top 10 highest revenue movie Title
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_10revenue=data.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index('Title')

# %%
sns.barplot(y=top_10revenue.index, x='Revenue (Millions)', data=top_10revenue)
plt.title("top 10 movies year wise")
plt.show()

# %%
# Finf the average Rating of movies year wise
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
avg_movies=data.groupby('Year')['Rating'].mean().reset_index()

# %%
avg_movies
# Out:
#     Year    Rating
# 0   2006  7.125000
# 1   2007  7.133962
# 2   2008  6.784615
# 3   2009  6.960784
# 4   2010  6.826667
# 5   2011  6.838095
# 6   2012  6.925000
# 7   2013  6.812088
# 8   2014  6.837755
# 9   2015  6.602362
# 10  2016  6.436700

# %%
avg_movies.values
# Out:
# array([[2006.        ,    7.125     ],
#        [2007.        ,    7.13396226],
#        [2008.        ,    6.78461538],
#        [2009.        ,    6.96078431],
#        [2010.        ,    6.82666667],
#        [2011.        ,    6.83809524],
#        [2012.        ,    6.925     ],
#        [2013.        ,    6.81208791],
#        [2014.        ,    6.8377551 ],
#        [2015.        ,    6.6023622 ],
#        [2016.        ,    6.43670034]])

# %%
sns.barplot(x='Year',y='Rating' ,data=avg_movies)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rating'>

# %%
# 19. Classify Movies Based on Ratings [Excellent, Good, and Average]
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data['Rating'].unique()
# Out:
# array([8.1, 7. , 7.3, 7.2, 6.2, 6.1, 8.3, 6.4, 7.1, 7.5, 7.8, 7.9, 7.7,
#        6.6, 8.2, 6.7, 8. , 6.5, 5.3, 6.8, 4.7, 5.9, 6.3, 5.6, 8.6, 7.6,
#        6.9, 2.7, 3.7, 5.8, 9. , 7.4, 4.1, 8.5, 8.8, 5.4, 6. , 5.7, 8.4,
#        5.2, 5.5, 4.8, 3.9, 4.9, 5.1, 5. , 4.3, 4.6, 4.2, 4. , 3.2, 4.5,
#        1.9, 3.5, 4.4])

# %%
data['Rating'].max()
# Out:
# 9.0

# %%
data['Rating'].min()
# Out:
# 1.9

# %%
def rating(rate):
    if rate>=8.5:
        return 'Excellent'
    elif rate>=5:
        return 'Good'
    else:
        return 'Average'

# %%
data['Rating Classify']=data['Rating'].apply(rating)

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 20 count number of Action Movies
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating Classify'],
#       dtype='object')

# %%
sum(data['Genre'].str.contains('Action', case=False))
# Out:
# 303

# %%
#Find Unique Values from Genre

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating Classify'],
#       dtype='object')

# %%
data['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
list1=[]
for value in data['Genre']:
    list1.append(value.split(','))
list1
# Out:
# [['Action', 'Adventure', 'Sci-Fi'],
#  ['Adventure', 'Mystery', 'Sci-Fi'],
#  ['Horror', 'Thriller'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Comedy', 'Drama', 'Music'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Biography'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Thriller'],
#  ['Biography', 'Drama'],
#  ['Drama', 'Mystery', 'Sci-Fi'],
#  ['Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Horror'],
#  ['Animation', 'Adventure', 'Comedy'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Comedy'],
# ...

# %%
list2=[]
for item1 in list1:
    for item2 in item1:
        list2.append(item2)
list2
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
# ...

# %%
list3=[]
for item in list2:
    if item not in list3:
        list3.append(item)
list3
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Mystery',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Romance',
#  'History',
#  'Crime',
#  'Western',
#  'War',
#  'Musical',
#  'Sport']

# %%
len(list3)
# Out:
# 20

# %% [markdown]
# # 22. How many Films of Each Genre Were made?
# genre_counter=Counter(list3)

# %%
from collections import Counter
genre_counter=Counter(list2)
genre_counter
# Out:
# Counter({'Action': 303,
#          'Adventure': 259,
#          'Sci-Fi': 120,
#          'Mystery': 106,
#          'Horror': 119,
#          'Thriller': 195,
#          'Animation': 49,
#          'Comedy': 279,
#          'Family': 51,
#          'Fantasy': 101,
#          'Drama': 513,
#          'Music': 16,
#          'Biography': 81,
#          'Romance': 141,
#          'History': 29,
#          'Crime': 150,
#          'Western': 7,
#          'War': 13,
#          'Musical': 5,
#          'Sport': 18})

# %%
# 22. How many Films of Each Genre Were made?
# from collection  import counter

# 23. does rating Affect The Revenue?
# barplot is use only for categorical data
# scatterplot is used for numeric data

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating Classify'],
#       dtype='object')

# %%
# scatter plot
sns. scatterplot(data=data, x='Rating',y='Revenue (Millions)')
plt.show()
