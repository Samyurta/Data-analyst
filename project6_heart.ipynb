# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('heart.csv')

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# 1. age
# 2. sex
# 3. cp: chest pain type (4 values)
#     - Value 0: typical angina
#     - Value 1: atypical angina
#     - Value 2: non-angina pain
#     - Value 3: asymptomatic
# 4. trestbps: resting blood pressure(in mm Hg on admission to the hospital
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: fasting blood sugar > 120 mg/dl(1=true; 0=false)
# 7. restecg: resting electrocardiographic results (values 0,1,2)
#     - Value 0: normal
#     - Value 1: having ST-T wave abnormality (T-wave inversions and/or ST elevation or depression of>0.05 mV)
#     - Value 2: Showing probable or definite left ventricular hypertrophy by Estes criteria
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina
# 10. oldpeak: oldpeak = ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
#     - value 1: upsloping
#     - value 2: flat
#     - value 3: downsloping
# 12. ca: number of major vessels (0-3) colored by flourosopy
# 13. thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
# 14. target: 0=less chance of heart attack, 1= more chance of heart attack
# - The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.isnull().sum(axis=0).any()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe(include='all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# check for duplicated data and drop then
data.duplicated().any()
# Out:
# True

# %%
data1=data.drop_duplicates()

# %%
data1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# # 2. Draw Correlation matrix
# -positive correlation
# -negative correlation
# -no correlation
# -strong positive correlation is near to 1 directly proportion
# -weak  positive correlation  is near to -1 inversally proportion

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
plt.figure(figsize=(15,5))
sns.heatmap(data.corr(), annot=True)
# annot=True is used to view the value  of all
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. How many people have heart disease, and how many dont have heart disease in this dataset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data1['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
plt.figure(figsize=(4,2))
sns.countplot(x=data['target'])
plt.show()

# %% [markdown]
# # 4. Find Count of Male and Female in this dataset.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data1['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(4,5))
sns.countplot(x=data1['sex'])
plt.xticks([0,1], ['Female','Male'])
plt.show()

# %% [markdown]
# # find Gender Distribution According to the target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='sex', data=data1, hue='target')
plt.xticks([0,1], ['Female','Male'])
plt.legend(labels=['No-Disease', 'Disease'])
plt.show()

# %% [markdown]
# # 6. check age  dIstribution  in the datasets

# %%
sns.displot(data['age'],bins=[20,25, 30,35,40, 45,50,55,60,65,70,75,80],kde=True)
plt.show()

# %%
# 7 check chest pain type
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['cp'].value_counts()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
sns.countplot(data['cp'])
plt.xticks([0,1,2,3],['typical angina', 'atypical angina', 'non-angina', 'asymptomatic'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 8. show the chest pain distribution as per terget variable

# %%
sns.countplot(data['cp'], hue=data['target'])
plt.legend(labels=['No-Disease','Disease'])
plt.xticks([0,1,2,3],['typical angina', 'atypical angina', 'non-angina', 'asymptomatic'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 9. show fasting blood sugar distribution according to the target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['fbs']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 1020    0
# 1021    0
# 1022    0
# 1023    0
# 1024    0
# Name: fbs, Length: 1025, dtype: int64

# %%
sns.countplot(data['fbs'], hue=data['target'])
plt.xticks([0,1],['false','true'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 10. Check resting blood pressure distribution

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['trestbps'].unique()
# Out:
# array([125, 140, 145, 148, 138, 100, 114, 160, 120, 122, 112, 132, 118,
#        128, 124, 106, 104, 135, 130, 136, 180, 129, 150, 178, 146, 117,
#        152, 154, 170, 134, 174, 144, 108, 123, 110, 142, 126, 192, 115,
#         94, 200, 165, 102, 105, 155, 172, 164, 156, 101], dtype=int64)

# %%
data['trestbps'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 11. compare resting blood pressure as per sex column

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['trestbps'], hue=data['sex'])
plt.xticks(rotation=75)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g=sns.FacetGrid(data,hue='sex', aspect=4)
g.map(sns.kdeplot,'trestbps',fill=True)
plt.legend(labels=['Male','Female'])

# %%
g=sns.FacetGrid(data,col='sex', )
g.map(sns.kdeplot,'trestbps',fill=True)
plt.show()

# %%
# 12 show distribution of serum cholestrol
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['chol'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,5))
sns.displot(data['chol'],bins=[100,200,300,400,500],kde=True,rug=True, color='red')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.displot(data['chol'],kind='kde')
plt.show()

# %% [markdown]
# # 13 plot continuous variables
# data.columns

# %%
categorical_var=[]
continuous_var=[]

for column in data.columns:
    if data[column].nunique()<=10:
        categorical_var.append(column)
    else:
        continuous_var.append(column)

# %%
categorical_var
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
continuous_var
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(continuous_var, figsize=(15,5))
plt.tight_layout()
plt.show()

# %%
data.hist(categorical_var, figsize=(15,5))
plt.tight_layout()
plt.show()

# %% [markdown]
# # pi chart

# %%
x=[10,20,30,40]
y=['c','c++','Java','Python']
ex=[0.3,0.0,0.0,0.0]
c=['r','b','g','y']
plt.pie(x, labels=y, autopct='%0.1f%%', startangle=90, counterclock=False, radius=0.8,explode=ex,colors=c, labeldistance=1.1, rotatelabels=True)
plt.title("PI chart")
plt.legend(loc=4, bbox_to_anchor=(1.2,1))
plt.show()
